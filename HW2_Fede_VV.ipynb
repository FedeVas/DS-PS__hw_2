# %% [markdown]
# # Импорты и настройка

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
# %load_ext sql

# %%
# Чтобы выводилось в pd.Dataframe, мне так привычнее
# %config SqlMagic.autopandas = True

# %%
# %sql postgresql://postgres:1234@localhost:5433/postgres

# %% [markdown]
# # Задания

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Создать таблицы со следующими структурами и загрузить данные из csv-файлов. Детали приведены ниже.
#
# Также в репозитории есть скриншот из DBeaver.

# %%
df_transactions = %sql SELECT * FROM transaction;
df_transactions.head()
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# 20000 rows affected.
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25         False
# 1               2           3         3120       2017-05-21          True
# 2               3          37          402       2017-10-16         False
# 3               4          88         3135       2017-08-31         False
# 4               5          78          787       2017-10-01          True
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
# ...

# %%
df_customers = %sql SELECT * FROM customer;
df_customers.head()
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# 4000 rows affected.
#    customer_id      first_name  last_name  gender         DOB  \
# 0            1         Laraine  Medendorp       F  1953-10-12
# 1            2             Eli    Bockman    Male  1980-12-16
# 2            3           Arlin     Dearle    Male  1954-01-20
# 3            4          Talbot               Male  1961-10-03
# 4            5  Sheila-kathryn     Calton  Female  1977-05-13
#
#                 job_title job_industry_category     wealth_segment  \
# 0     Executive Secretary                Health      Mass Customer
# 1  Administrative Officer    Financial Services      Mass Customer
# 2      Recruiting Manager              Property      Mass Customer
# 3                                            IT      Mass Customer
# 4           Senior Editor                   n/a  Affluent Customer
#
#   deceased_indicator owns_car              address  postcode            state  \
# ...

# %% [markdown]
# ## Задание 2.1

# %% [markdown]
# Вывести все уникальные бренды, у которых стандартная стоимость выше 1500 долларов.

# %%
query = """
SELECT DISTINCT(brand)
FROM transaction
WHERE standard_cost > 1500;
"""

df_2_1 = %sql $query
df_2_1
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# 6 rows affected.
#             brand
# 0      OHM Cycles
# 1        WeareA2B
# 2   Trek Bicycles
# 3           Solex
# 4  Norco Bicycles
# 5  Giant Bicycles

# %% [markdown]
# ## Задание 2.2

# %% [markdown]
# Вывести все подтвержденные транзакции за период '2017-04-01' по '2017-04-09' включительно.

# %%
query = """
SELECT *
FROM transaction
WHERE order_status = 'Approved'
  AND transaction_date BETWEEN '2017-04-01' AND '2017-04-09';
"""

df_2_2 = %sql $query
df_2_2
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# 531 rows affected.
#      transaction_id  product_id  customer_id transaction_date  online_order  \
# 0                17          79         2426       2017-04-03         False
# 1                19          54         2268       2017-04-06          True
# 2                23          37         2001       2017-04-08          True
# 3                83           0         3398       2017-04-01          True
# 4                89           0         2682       2017-04-04          True
# ..              ...         ...          ...              ...           ...
# 526           19655           0          336       2017-04-09          True
# 527           19853           7         3072       2017-04-02         False
# 528           19899          57          325       2017-04-06         False
# 529           19968           0         2751       2017-04-06         False
# ...

# %% [markdown]
# ## Задание 2.3

# %% [markdown]
# Вывести все профессии у клиентов из сферы IT или Financial Services, которые начинаются с фразы 'Senior'.

# %%
query = """
SELECT DISTINCT(job_title)
FROM customer
WHERE (job_industry_category = 'IT' 
  OR job_industry_category = 'Financial Services')
  AND job_title LIKE 'Senior%'; 
"""

df_2_3 = %sql $query
df_2_3
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# 6 rows affected.
#                   job_title
# 0    Senior Cost Accountant
# 1          Senior Developer
# 2             Senior Editor
# 3  Senior Financial Analyst
# 4   Senior Quality Engineer
# 5    Senior Sales Associate

# %% [markdown]
# ## Задание 2.4

# %% [markdown]
# Вывести все бренды, которые закупают клиенты, работающие в сфере Financial Services

# %%
query = """
SELECT DISTINCT(brand)
FROM transaction AS t
JOIN customer AS c ON t.customer_id=c.customer_id
WHERE c.job_industry_category = 'Financial Services'; 
"""

df_2_4 = %sql $query
df_2_4
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# 7 rows affected.
#             brand
# 0
# 1   Trek Bicycles
# 2        WeareA2B
# 3           Solex
# 4  Giant Bicycles
# 5      OHM Cycles
# 6  Norco Bicycles

# %% [markdown]
# ## Задание 2.5

# %% [markdown]
# Вывести 10 клиентов, которые оформили онлайн-заказ продукции из брендов 'Giant Bicycles', 'Norco Bicycles', 'Trek Bicycles'.

# %%
query = """
SELECT DISTINCT c.customer_id, c.first_name, c.last_name
FROM transaction t
JOIN customer c ON t.customer_id = c.customer_id
WHERE t.online_order = TRUE
  AND t.brand IN ('Giant Bicycles', 'Norco Bicycles', 'Trek Bicycles')
LIMIT 10; 
"""

df_2_5 = %sql $query
df_2_5
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# 10 rows affected.
#    customer_id first_name    last_name
# 0          742     Dexter      Robelin
# 1         3123       Tina  Riggulsford
# 2           20     Basile        Firth
# 3         1894     Patten      Laytham
# 4         3426        Ron        Dilon
# 5         1179      Kerry    Pashenkov
# 6         3491     Leanna        Cromb
# 7         2201     Trisha       Basset
# 8         1521    Pernell      Duffett
# 9         2431       Alvy      Tyndall

# %% [markdown]
# ## Задание 2.6

# %% [markdown]
# Вывести всех клиентов, у которых нет транзакций.

# %%
# %%time
query = """
SELECT c.*
FROM customer c
LEFT JOIN transaction t ON c.customer_id = t.customer_id
WHERE t.customer_id IS NULL;
 
"""

df_2_6 = %sql $query
df_2_6
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# 507 rows affected.
# CPU times: total: 15.6 ms
# Wall time: 7.92 ms
#      customer_id first_name last_name  gender         DOB  \
# 0            852      Andie    Bonney  Female  2000-11-04
# 1            869      Addia     Abels  Female  1984-03-11
# 2           1373   Shaylynn    Epsley  Female  1958-09-23
# 3           3540        Ali     Naris    Male  1954-08-27
# 4           3541      Aloin   Harhoff    Male  1986-01-03
# ..           ...        ...       ...     ...         ...
# 502         3996    Rosalia  Halgarth  Female  1975-08-09
# 503         3997     Blanch    Nisuis  Female  2001-07-13
# 504         3998     Sarene   Woolley       U        None
# 505         3999  Patrizius              Male  1973-10-24
# 506         4000      Kippy   Oldland    Male  1991-11-05
#
#                     job_title job_industry_category     wealth_segment  \
# 0        Compensation Analyst    Financial Services  Affluent Customer
# ...

# %% [markdown]
# Вариант 2

# %%
# %%time
query = """
SELECT *
FROM customer c
WHERE NOT EXISTS (
    SELECT 1
    FROM transaction t
    WHERE t.customer_id = c.customer_id
);
"""

df_2_6_1 = %sql $query
df_2_6_1
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# 507 rows affected.
# CPU times: total: 15.6 ms
# Wall time: 12 ms
#      customer_id first_name last_name  gender         DOB  \
# 0            852      Andie    Bonney  Female  2000-11-04
# 1            869      Addia     Abels  Female  1984-03-11
# 2           1373   Shaylynn    Epsley  Female  1958-09-23
# 3           3540        Ali     Naris    Male  1954-08-27
# 4           3541      Aloin   Harhoff    Male  1986-01-03
# ..           ...        ...       ...     ...         ...
# 502         3996    Rosalia  Halgarth  Female  1975-08-09
# 503         3997     Blanch    Nisuis  Female  2001-07-13
# 504         3998     Sarene   Woolley       U        None
# 505         3999  Patrizius              Male  1973-10-24
# 506         4000      Kippy   Oldland    Male  1991-11-05
#
#                     job_title job_industry_category     wealth_segment  \
# 0        Compensation Analyst    Financial Services  Affluent Customer
# ...

# %% [markdown]
# Вариант 3

# %%
# %%time
query = """
SELECT *
FROM customer
WHERE customer_id NOT IN (
    SELECT customer_id
    FROM transaction
);
"""

df_2_6_2 = %sql $query
df_2_6_2
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# 507 rows affected.
# CPU times: total: 0 ns
# Wall time: 8.66 ms
#      customer_id first_name last_name  gender         DOB  \
# 0            852      Andie    Bonney  Female  2000-11-04
# 1            869      Addia     Abels  Female  1984-03-11
# 2           1373   Shaylynn    Epsley  Female  1958-09-23
# 3           3540        Ali     Naris    Male  1954-08-27
# 4           3541      Aloin   Harhoff    Male  1986-01-03
# ..           ...        ...       ...     ...         ...
# 502         3996    Rosalia  Halgarth  Female  1975-08-09
# 503         3997     Blanch    Nisuis  Female  2001-07-13
# 504         3998     Sarene   Woolley       U        None
# 505         3999  Patrizius              Male  1973-10-24
# 506         4000      Kippy   Oldland    Male  1991-11-05
#
#                     job_title job_industry_category     wealth_segment  \
# 0        Compensation Analyst    Financial Services  Affluent Customer
# ...

# %% [markdown]
# Первый запрос, с использованием "WHERE t.customer_id IS NULL;" оказался эффективнее по времени запроса.

# %% [markdown]
# ## Задание 2.7

# %% [markdown]
# Вывести всех клиентов из IT, у которых транзакции с максимальной стандартной стоимостью.

# %%
query = """
SELECT DISTINCT c.*
FROM customer c
JOIN transaction t ON c.customer_id = t.customer_id
WHERE c.job_industry_category = 'IT'
  AND t.standard_cost = (
    SELECT MAX(t2.standard_cost)
    FROM transaction t2
    JOIN customer c2 ON t2.customer_id = c2.customer_id
    WHERE c2.job_industry_category = 'IT'
  );
"""

df_2_7 = %sql $query
df_2_7
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# 9 rows affected.
#    customer_id first_name last_name  gender         DOB  \
# 0           34   Jephthah  Bachmann       U  1843-12-21
# 1          893      Gibby  Fearnley    Male  1983-09-11
# 2          975  Goldarina   Rzehorz       U        None
# 3         1672     Sharla    Creebo  Female  1963-04-27
# 4         1773   Nickolas   Guittet       U        None
# 5         1918      Devin  Sandeson       U        None
# 6         2913    Padraic    Bonnar    Male  1955-07-11
# 7         3151      Thorn   Choffin       U        None
# 8         3473  Sanderson   Alloway       U        None
#
#                        job_title job_industry_category     wealth_segment  \
# 0                Legal Assistant                    IT  Affluent Customer
# 1                    Geologist I                    IT      Mass Customer
# 2       Automation Specialist IV                    IT      Mass Customer
# ...

# %% [markdown]
# ## Задание 2.8

# %% [markdown]
# Вывести всех клиентов из сферы IT и Health, у которых есть подтвержденные транзакции за период '2017-07-07' по '2017-07-17'.

# %%
query = """
SELECT DISTINCT c.*
FROM customer c
JOIN transaction t ON c.customer_id = t.customer_id
WHERE c.job_industry_category IN ('IT', 'Health')
  AND t.order_status = 'Approved'
  AND t.transaction_date BETWEEN '2017-07-07' AND '2017-07-17';
"""

df_2_8 = %sql $query
df_2_8
# Out:
#  * postgresql://postgres:***@localhost:5433/postgres
# 115 rows affected.
#      customer_id first_name last_name  gender         DOB  \
# 0             22    Deeanne  Durtnell  Female  1962-12-10
# 1             28        Fee   Zellmer    Male  1973-09-30
# 2             41   Basilius     Coupe    Male  1976-04-14
# 3             47    Matthew  Jeaycock    Male  1992-10-22
# 4            104     Odille   Panketh  Female  1978-06-06
# ..           ...        ...       ...     ...         ...
# 110         3255  Sutherlan     Truin       U        None
# 111         3288       Fair     Dewen       U        None
# 112         3360     Joelie   Sherlaw  Female  1963-03-23
# 113         3365    Karlens   Chaffyn       U        None
# 114         3482       Roch   Rilston  Female  2000-05-18
#
#                     job_title job_industry_category     wealth_segment  \
# 0                                                IT      Mass Customer
# ...
